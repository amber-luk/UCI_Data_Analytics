# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the northern hemisphere tends to be warmer this time of year than the southern hemisphere. This may be due to the tilt of the earth.
# * There doesn't appear to be a strong relationship between latitude and humidity, however while most degrees of latitude have varying degrees of humidity, the area along the equator at 0 degrees latitude has much smaller variability and sits pretty consistelty at nearly 100% humidity.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 20, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind, and a rather extreme outlier at just over 40 degrees of latitude with close to 50 mph winds.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
import urllib

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities[0:5])
# Out:
# 604
# ['okha', 'rostusa', 'saldanha', 'souillac', 'hithadhoo']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print(
"""
Beginning Data Retrieval
-----------------------------""")

settings = {"units": "metric", "appid": api_key}
weather_data = []

for city in cities: 
    try: 
        weather_data.append(owm.get_current(city, **settings))
        print(f"Processing Record {cities.index(city)} | {city}")
    except urllib.error.HTTPError: 
        print(f"{city} not found. Skipping...")

print(
"""
-----------------------------
Data Retrieval Complete
-----------------------------""")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | okha
# rostusa not found. Skipping...
# Processing Record 2 | saldanha
# Processing Record 3 | souillac
# Processing Record 4 | hithadhoo
# Processing Record 5 | lagoa
# palabuhanratu not found. Skipping...
# Processing Record 7 | vila velha
# nguiu not found. Skipping...
# Processing Record 9 | hilo
# Processing Record 10 | marsh harbour
# Processing Record 11 | mataura
# Processing Record 12 | vanavara
# Processing Record 13 | puerto colombia
# Processing Record 14 | lima
# Processing Record 15 | barrow
# kamenskoye not found. Skipping...
# Processing Record 17 | cabo san lucas
# belushya guba not found. Skipping...
# Processing Record 19 | naze
# Processing Record 20 | gaeta
# Processing Record 21 | rawson
# Processing Record 22 | ilulissat
# taolanaro not found. Skipping...
# Processing Record 24 | bluff
# Processing Record 25 | sitka
# Processing Record 26 | broome
# Processing Record 27 | mola di bari
# Processing Record 28 | belaya gora
# qabis not found. Skipping...
# Processing Record 30 | thompson
# barentsburg not found. Skipping...
# Processing Record 32 | airai
# Processing Record 33 | jamestown
# Processing Record 34 | chokurdakh
# Processing Record 35 | georgetown
# Processing Record 36 | grand gaube
# Processing Record 37 | turukhansk
# illoqqortoormiut not found. Skipping...
# Processing Record 39 | punta arenas
# Processing Record 40 | qaanaaq
# Processing Record 41 | gopalpur
# Processing Record 42 | chuy
# Processing Record 43 | tucumcari
# Processing Record 44 | tynda
# Processing Record 45 | rikitea
# Processing Record 46 | rio gallegos
# Processing Record 47 | kapaa
# Processing Record 48 | cap malheureux
# Processing Record 49 | ushuaia
# Processing Record 50 | manta
# Processing Record 51 | richards bay
# Processing Record 52 | tiksi
# Processing Record 53 | avarua
# Processing Record 54 | nanortalik
# Processing Record 55 | la ronge
# Processing Record 56 | poso
# Processing Record 57 | ribeira grande
# bengkulu not found. Skipping...
# Processing Record 59 | norman wells
# Processing Record 60 | shelburne
# Processing Record 61 | albany
# Processing Record 62 | atikokan
# grand river south east not found. Skipping...
# Processing Record 64 | lavrentiya
# Processing Record 65 | deputatskiy
# Processing Record 66 | kajiado
# Processing Record 67 | dafeng
# Processing Record 68 | ancud
# Processing Record 69 | kidal
# amderma not found. Skipping...
# Processing Record 71 | cervo
# Processing Record 72 | atuona
# vaitupu not found. Skipping...
# Processing Record 74 | meulaboh
# Processing Record 75 | imperia
# Processing Record 76 | steinbach
# Processing Record 77 | cidreira
# Processing Record 78 | east london
# Processing Record 79 | bonthe
# Processing Record 80 | muros
# Processing Record 81 | sorland
# Processing Record 82 | port alfred
# Processing Record 83 | luanda
# umzimvubu not found. Skipping...
# Processing Record 85 | evans
# Processing Record 86 | saint-philippe
# Processing Record 87 | lebu
# Processing Record 88 | linxia
# Processing Record 89 | lorengau
# Processing Record 90 | butaritari
# Processing Record 91 | suhbaatar
# Processing Record 92 | vaini
# santarem not found. Skipping...
# Processing Record 94 | praia da vitoria
# Processing Record 95 | huarmey
# Processing Record 96 | ambilobe
# Processing Record 97 | port lincoln
# Processing Record 98 | kiraoli
# Processing Record 99 | gobabis
# Processing Record 100 | cape town
# Processing Record 101 | ust-nera
# Processing Record 102 | mar del plata
# Processing Record 103 | vila franca do campo
# Processing Record 104 | tianpeng
# Processing Record 105 | saskylakh
# Processing Record 106 | talnakh
# Processing Record 107 | mkushi
# Processing Record 108 | vestmannaeyjar
# Processing Record 109 | svetlogorsk
# Processing Record 110 | borba
# Processing Record 111 | canutama
# Processing Record 112 | yellowknife
# Processing Record 113 | havelock
# Processing Record 114 | ilhabela
# Processing Record 115 | tuktoyaktuk
# Processing Record 116 | saint-augustin
# Processing Record 117 | ahipara
# Processing Record 118 | fairbanks
# Processing Record 119 | severo-kurilsk
# Processing Record 120 | kisangani
# Processing Record 121 | rafaela
# Processing Record 122 | hermanus
# Processing Record 123 | pochutla
# Processing Record 124 | itarema
# Processing Record 125 | loa janan
# Processing Record 126 | port augusta
# Processing Record 127 | labuhan
# Processing Record 128 | nuuk
# Processing Record 129 | polunochnoye
# Processing Record 130 | kodiak
# Processing Record 131 | slave lake
# Processing Record 132 | evanston
# Processing Record 133 | zlobin
# Processing Record 134 | hobart
# Processing Record 135 | vanimo
# Processing Record 136 | nhulunbuy
# Processing Record 137 | marmaris
# Processing Record 138 | chumikan
# Processing Record 139 | mandan
# Processing Record 140 | katsuura
# Processing Record 141 | simbahan
# Processing Record 142 | badvel
# Processing Record 143 | upernavik
# Processing Record 144 | hollister
# Processing Record 145 | hofn
# Processing Record 146 | maumere
# Processing Record 147 | juba
# Processing Record 148 | faya
# Processing Record 149 | mount pleasant
# Processing Record 150 | tabou
# Processing Record 151 | susanville
# Processing Record 152 | muzhi
# Processing Record 153 | vao
# Processing Record 154 | belmopan
# Processing Record 155 | busselton
# Processing Record 156 | haines junction
# Processing Record 157 | tazovskiy
# Processing Record 158 | sambava
# Processing Record 159 | hailey
# Processing Record 160 | kuruman
# Processing Record 161 | comodoro rivadavia
# Processing Record 162 | dikson
# Processing Record 163 | blois
# krasnoselkup not found. Skipping...
# Processing Record 165 | coos bay
# Processing Record 166 | kiunga
# Processing Record 167 | new norfolk
# Processing Record 168 | colac
# tabialan not found. Skipping...
# Processing Record 170 | hovd
# Processing Record 171 | makakilo city
# Processing Record 172 | egvekinot
# Processing Record 173 | bani walid
# Processing Record 174 | zyryanka
# Processing Record 175 | weligama
# Processing Record 176 | tuatapere
# attawapiskat not found. Skipping...
# Processing Record 178 | beltangadi
# Processing Record 179 | castro
# Processing Record 180 | provideniya
# Processing Record 181 | roma
# Processing Record 182 | kahului
# Processing Record 183 | kamenka
# Processing Record 184 | kitimat
# Processing Record 185 | esperance
# Processing Record 186 | praia
# Processing Record 187 | clyde river
# Processing Record 188 | petropavlovsk-kamchatskiy
# Processing Record 189 | port elizabeth
# Processing Record 190 | saurimo
# Processing Record 191 | nampa
# Processing Record 192 | quatre cocos
# ardahan not found. Skipping...
# Processing Record 194 | invermere
# Processing Record 195 | kruisfontein
# Processing Record 196 | codrington
# Processing Record 197 | qinhuangdao
# Processing Record 198 | bredasdorp
# Processing Record 199 | kaitangata
# Processing Record 200 | mount isa
# Processing Record 201 | kirkland lake
# Processing Record 202 | leshukonskoye
# Processing Record 203 | puerto ayora
# Processing Record 204 | batagay-alyta
# Processing Record 205 | ondangwa
# tasbuget not found. Skipping...
# Processing Record 207 | muhos
# Processing Record 208 | vardo
# Processing Record 209 | cap-aux-meules
# Processing Record 210 | inta
# Processing Record 211 | togul
# nizhneyansk not found. Skipping...
# Processing Record 213 | nikolskoye
# Processing Record 214 | arraial do cabo
# Processing Record 215 | dicabisagan
# Processing Record 216 | san patricio
# Processing Record 217 | inhambane
# Processing Record 218 | seoul
# Processing Record 219 | goure
# Processing Record 220 | neiafu
# Processing Record 221 | novita
# Processing Record 222 | saint george
# Processing Record 223 | coihaique
# Processing Record 224 | balkanabat
# Processing Record 225 | saint-joseph
# Processing Record 226 | ranfurly
# Processing Record 227 | yulara
# Processing Record 228 | ventersburg
# Processing Record 229 | simao
# Processing Record 230 | pau dos ferros
# Processing Record 231 | carnarvon
# lolua not found. Skipping...
# Processing Record 233 | san nicolas
# Processing Record 234 | pangody
# Processing Record 235 | port pirie
# Processing Record 236 | biltine
# Processing Record 237 | itanhaem
# dzhusaly not found. Skipping...
# Processing Record 239 | port blair
# Processing Record 240 | aykhal
# Processing Record 241 | tanabe
# Processing Record 242 | khatanga
# Processing Record 243 | maryville
# olafsvik not found. Skipping...
# Processing Record 245 | ossora
# Processing Record 246 | lawton
# Processing Record 247 | touros
# Processing Record 248 | hasaki
# Processing Record 249 | berlevag
# Processing Record 250 | fortuna
# Processing Record 251 | mayya
# Processing Record 252 | tasiilaq
# Processing Record 253 | sur
# Processing Record 254 | mineiros
# Processing Record 255 | amahai
# Processing Record 256 | yumen
# Processing Record 257 | cherskiy
# Processing Record 258 | petatlan
# Processing Record 259 | hammerfest
# Processing Record 260 | lompoc
# Processing Record 261 | kawalu
# Processing Record 262 | olavarria
# Processing Record 263 | bethel
# Processing Record 264 | bambous virieux
# Processing Record 265 | aksarka
# Processing Record 266 | dehloran
# Processing Record 267 | okhotsk
# Processing Record 268 | aranos
# Processing Record 269 | saint-pierre
# Processing Record 270 | sao filipe
# Processing Record 271 | bubaque
# Processing Record 272 | yorosso
# Processing Record 273 | vostok
# Processing Record 274 | torbay
# Processing Record 275 | paita
# Processing Record 276 | ouadda
# bandar penggaram not found. Skipping...
# Processing Record 278 | aliquippa
# Processing Record 279 | faanui
# Processing Record 280 | nelson bay
# Processing Record 281 | valparaiso
# Processing Record 282 | aklavik
# Processing Record 283 | sedalia
# Processing Record 284 | morondava
# Processing Record 285 | salinopolis
# Processing Record 286 | klaksvik
# Processing Record 287 | karratha
# Processing Record 288 | havoysund
# Processing Record 289 | flagstaff
# Processing Record 290 | ust-tsilma
# Processing Record 291 | te anau
# Processing Record 292 | seabra
# Processing Record 293 | narsaq
# Processing Record 294 | harper
# Processing Record 295 | launceston
# Processing Record 296 | bandarbeyla
# Processing Record 297 | palencia
# Processing Record 298 | palmer
# Processing Record 299 | bykov
# Processing Record 300 | muriwai beach
# Processing Record 301 | salalah
# Processing Record 302 | constitucion
# Processing Record 303 | gat
# Processing Record 304 | geraldton
# Processing Record 305 | wajir
# Processing Record 306 | yerbogachen
# mendahara not found. Skipping...
# Processing Record 308 | gazojak
# Processing Record 309 | samana
# Processing Record 310 | lata
# Processing Record 311 | chany
# Processing Record 312 | panjab
# Processing Record 313 | longyearbyen
# Processing Record 314 | champerico
# Processing Record 315 | zhigansk
# Processing Record 316 | ponta do sol
# Processing Record 317 | guerrero negro
# Processing Record 318 | nome
# Processing Record 319 | kokopo
# Processing Record 320 | pelym
# Processing Record 321 | pamyat parizhskoy kommuny
# Processing Record 322 | marathon
# Processing Record 323 | port hedland
# Processing Record 324 | oum hadjer
# Processing Record 325 | ballina
# Processing Record 326 | fare
# Processing Record 327 | ierapetra
# Processing Record 328 | vestmanna
# Processing Record 329 | kenai
# tsihombe not found. Skipping...
# Processing Record 331 | locri
# Processing Record 332 | turayf
# Processing Record 333 | puerto quijarro
# Processing Record 334 | mushie
# Processing Record 335 | saint-leu
# Processing Record 336 | chaykovskiy
# Processing Record 337 | trairi
# korla not found. Skipping...
# Processing Record 339 | vydrino
# Processing Record 340 | alexandria
# texcalac not found. Skipping...
# Processing Record 342 | copala
# Processing Record 343 | steamboat springs
# Processing Record 344 | aljezur
# bafra not found. Skipping...
# Processing Record 346 | durango
# Processing Record 347 | westlock
# Processing Record 348 | namibe
# Processing Record 349 | husavik
# Processing Record 350 | khem karan
# Processing Record 351 | fareham
# Processing Record 352 | mogadishu
# Processing Record 353 | sinnamary
# Processing Record 354 | rivadavia
# Processing Record 355 | kuito
# Processing Record 356 | iskateley
# Processing Record 357 | raudeberg
# Processing Record 358 | kangalassy
# Processing Record 359 | vila
# Processing Record 360 | ormara
# Processing Record 361 | jinchang
# Processing Record 362 | charters towers
# Processing Record 363 | shirokiy
# Processing Record 364 | adjumani
# Processing Record 365 | teya
# Processing Record 366 | shimoda
# sumen not found. Skipping...
# Processing Record 368 | brokopondo
# Processing Record 369 | coahuayana
# Processing Record 370 | oussouye
# Processing Record 371 | rajapur
# Processing Record 372 | meiktila
# Processing Record 373 | general roca
# mys shmidta not found. Skipping...
# sumbawa not found. Skipping...
# Processing Record 376 | mpika
# Processing Record 377 | guia de isora
# Processing Record 378 | sydney
# Processing Record 379 | teahupoo
# Processing Record 380 | poum
# Processing Record 381 | atar
# Processing Record 382 | belmonte
# Processing Record 383 | at-bashi
# Processing Record 384 | nahavand
# Processing Record 385 | bathsheba
# Processing Record 386 | nsanje
# Processing Record 387 | kumluca
# Processing Record 388 | lake city
# Processing Record 389 | buchanan
# Processing Record 390 | lebedinyy
# Processing Record 391 | tripoli
# Processing Record 392 | cockburn town
# Processing Record 393 | viransehir
# Processing Record 394 | santiago del estero
# Processing Record 395 | hambantota
# Processing Record 396 | cuamba
# sentyabrskiy not found. Skipping...
# Processing Record 398 | flic en flac
# Processing Record 399 | sabang
# Processing Record 400 | nisia floresta
# Processing Record 401 | victoria
# Processing Record 402 | monclova
# Processing Record 403 | qasigiannguit
# Processing Record 404 | sapa
# chagda not found. Skipping...
# Processing Record 406 | kaoma
# Processing Record 407 | puksoozero
# Processing Record 408 | atbasar
# Processing Record 409 | coyah
# Processing Record 410 | lukovetskiy
# Processing Record 411 | port-cartier
# Processing Record 412 | muscatine
# Processing Record 413 | namatanai
# Processing Record 414 | riyadh
# Processing Record 415 | emerald
# Processing Record 416 | rio de janeiro
# Processing Record 417 | wilmington
# Processing Record 418 | high rock
# Processing Record 419 | lingao
# Processing Record 420 | wloclawek
# Processing Record 421 | kaset sombun
# Processing Record 422 | suifenhe
# grand centre not found. Skipping...
# Processing Record 424 | kavieng
# Processing Record 425 | henties bay
# Processing Record 426 | forestville
# Processing Record 427 | umm lajj
# Processing Record 428 | sinjar
# Processing Record 429 | qaqortoq
# mazulskiy not found. Skipping...
# samusu not found. Skipping...
# Processing Record 432 | sunyani
# Processing Record 433 | santa maria
# Processing Record 434 | pacific grove
# sorvag not found. Skipping...
# Processing Record 436 | banda aceh
# Processing Record 437 | bima
# Processing Record 438 | chenghai
# Processing Record 439 | grindavik
# Processing Record 440 | hue
# Processing Record 441 | contai
# Processing Record 442 | half moon bay
# Processing Record 443 | ankang
# Processing Record 444 | angoche
# Processing Record 445 | talcahuano
# Processing Record 446 | phek
# Processing Record 447 | eidsvag
# Processing Record 448 | thinadhoo
# Processing Record 449 | san cristobal
# Processing Record 450 | qingdao
# Processing Record 451 | caconda
# Processing Record 452 | mazara del vallo
# Processing Record 453 | artyom
# Processing Record 454 | nago
# Processing Record 455 | kijang
# Processing Record 456 | san carlos
# Processing Record 457 | buriti dos lopes
# yomitan not found. Skipping...
# Processing Record 459 | tucuman
# Processing Record 460 | praxedis guerrero
# pousat not found. Skipping...
# Processing Record 462 | boo
# saleaula not found. Skipping...
# ngukurr not found. Skipping...
# Processing Record 465 | preobrazheniye
# Processing Record 466 | jacareacanga
# Processing Record 467 | hamilton
# Processing Record 468 | yamada
# Processing Record 469 | puri
# Processing Record 470 | escanaba
# Processing Record 471 | dongying
# Processing Record 472 | srednekolymsk
# Processing Record 473 | nizhnevartovsk
# Processing Record 474 | upington
# Processing Record 475 | mahebourg
# Processing Record 476 | rurrenabaque
# Processing Record 477 | kalemie
# Processing Record 478 | vadlapudi
# Processing Record 479 | staszow
# Processing Record 480 | chapeco
# leshan not found. Skipping...
# gangotri not found. Skipping...
# Processing Record 483 | vilhena
# Processing Record 484 | ashcroft
# asau not found. Skipping...
# Processing Record 486 | maningrida
# Processing Record 487 | zhangye
# ruatoria not found. Skipping...
# labutta not found. Skipping...
# Processing Record 490 | bramsche
# Processing Record 491 | piacabucu
# Processing Record 492 | bolshaya rechka
# Processing Record 493 | glenluce
# Processing Record 494 | miri
# Processing Record 495 | vila do maio
# Processing Record 496 | tres arroyos
# Processing Record 497 | samarai
# el faiyum not found. Skipping...
# Processing Record 499 | yangambi
# Processing Record 500 | kavaratti
# Processing Record 501 | sheffield
# Processing Record 502 | canoinhas
# shchelyayur not found. Skipping...
# Processing Record 504 | sabha
# Processing Record 505 | whitehorse
# Processing Record 506 | nola
# bargal not found. Skipping...
# Processing Record 508 | katete
# Processing Record 509 | bajil
# Processing Record 510 | san blas
# Processing Record 511 | kangaatsiaq
# ondorhaan not found. Skipping...
# Processing Record 513 | northam
# Processing Record 514 | nemuro
# Processing Record 515 | alofi
# Processing Record 516 | adrar
# Processing Record 517 | blagoyevo
# Processing Record 518 | kaeo
# Processing Record 519 | mongoumba
# Processing Record 520 | roald
# Processing Record 521 | guarapari
# Processing Record 522 | bolobo
# Processing Record 523 | brnakot
# Processing Record 524 | oistins
# Processing Record 525 | eenhana
# Processing Record 526 | finote selam
# Processing Record 527 | acireale
# Processing Record 528 | prieska
# Processing Record 529 | zhezkazgan
# Processing Record 530 | atasu
# Processing Record 531 | tautira
# Processing Record 532 | solnechnyy
# waw not found. Skipping...
# Processing Record 534 | north bend
# Processing Record 535 | otradnaya
# Processing Record 536 | arlit
# Processing Record 537 | pevek
# Processing Record 538 | manicore
# Processing Record 539 | sungaipenuh
# Processing Record 540 | otradnoye
# Processing Record 541 | sharjah
# Processing Record 542 | nzerekore
# Processing Record 543 | biharamulo
# Processing Record 544 | grand-santi
# Processing Record 545 | turka
# Processing Record 546 | pudozh
# Processing Record 547 | sao jose da coroa grande
# Processing Record 548 | sume
# Processing Record 549 | nshamba
# Processing Record 550 | iqaluit
# Processing Record 551 | pijijiapan
# halalo not found. Skipping...
# Processing Record 553 | coquimbo
# Processing Record 554 | port macquarie
# Processing Record 555 | kyabram
# Processing Record 556 | marquette
# Processing Record 557 | la dorada
# Processing Record 558 | tonantins
# Processing Record 559 | sao joao da barra
# kushmurun not found. Skipping...
# toamua not found. Skipping...
# Processing Record 562 | moindou
# barbar not found. Skipping...
# Processing Record 564 | krasnovishersk
# Processing Record 565 | kloulklubed
# Processing Record 566 | taft
# Processing Record 567 | hauterive
# Processing Record 568 | vredendal
# Processing Record 569 | parvatsar
# Processing Record 570 | taybad
# katsiveli not found. Skipping...
# Processing Record 572 | olinda
# Processing Record 573 | parana
# Processing Record 574 | hami
# yusva not found. Skipping...
# Processing Record 576 | malartic
# Processing Record 577 | bogovarovo
# Processing Record 578 | zhanaozen
# Processing Record 579 | kununurra
# Processing Record 580 | koslan
# bur gabo not found. Skipping...
# Processing Record 582 | muswellbrook
# Processing Record 583 | chanika
# Processing Record 584 | marsaxlokk
# Processing Record 585 | chifeng
# Processing Record 586 | honiara
# Processing Record 587 | rafai
# Processing Record 588 | kirakira
# Processing Record 589 | aasiaat
# Processing Record 590 | uvat
# Processing Record 591 | mangaluru
# Processing Record 592 | nyahururu
# Processing Record 593 | istok
# mentok not found. Skipping...
# Processing Record 595 | aurillac
# Processing Record 596 | santa cruz
# Processing Record 597 | salta
# Processing Record 598 | flinders
# Processing Record 599 | saint anthony
# Processing Record 600 | san quintin
# Processing Record 601 | matsubase
# Processing Record 602 | les cayes
# Processing Record 603 | chirilagua
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
summary = ["coord.lon", "coord.lat","main.temp", "main.humidity", "clouds.all", "wind.speed"]
data = [response(*summary) for response in weather_data]
print(len(data))
print(len(weather_data))
cities_2 = [response("name") for response in weather_data]
len(cities_2)
weather_data_df = pd.DataFrame(data, index=cities_2)
weather_data_df.head()
# Out:
# 543
# 543
#                 0      1      2    3   4     5
# Okha       142.95  53.59  -4.09  100  32  4.32
# Saldanha    -6.55  41.42   5.31   88  32  0.77
# Souillac    -0.60  45.60  11.07   93   0  2.10
# Hithadhoo   73.08  -0.60  27.96  100  64  3.77
# Lagoa       -8.45  37.14  11.89   87   0  2.60

# %%
column_names = ["Longitude", "Latitude", "Temperature", "Humidity", "% Cloudiness", "Wind Speed"]
weather_data_df = pd.DataFrame(data, index=cities_2, columns=column_names)
weather_data_df.head()
weather_data_df.to_csv("Weather_Data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data_df["Temperature"], marker="o", color="b", edgecolor="black")
plt.grid()
plt.title("City Lattitude vs. Max Temperature (04/01/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlim(-80, 100)
plt.savefig("City_Lat_vs_Max_Temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data_df["Humidity"], marker="o", color="b", edgecolor="black")
plt.grid()
plt.title("City Lattitude vs. Humidity (04/01/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-80, 100)
plt.savefig("Lat_vs_Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data_df["% Cloudiness"], marker="o", color="b", edgecolor="black")
plt.grid()
plt.title("City Lattitude vs. Cloudiness (04/01/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-80, 100)
plt.savefig("Lat_vs_Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data_df["Latitude"], weather_data_df["Wind Speed"], marker="o", color="b", edgecolor="black")
plt.grid()
plt.title("City Lattitude vs. Wind Speed (04/01/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-80, 100)
plt.savefig("Lat_vs_Wind_Speed.png")
